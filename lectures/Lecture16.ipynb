# %%
using Plots, FFTW, Interact
# Out:
# WebIO._IJuliaInit()

# %%
# a dfunction with a Taylor-Fourier seris
f = θ -> exp(exp(im*θ)) # exp(z) = Σ z^k/k!
n = 10
θ = range(0,2π; length=n+1)[1:n]


[sum(exp(-im*k*θ[j]) * f(θ[j]) for j=1:n)/n for k=0:n-1]

fft(f.(θ))/n
# Out:
# 10-element Vector{ComplexF64}:
#      1.0000002755731923 + 2.6709684293530373e-17im
#      1.0000000250521084 - 9.044021946622918e-17im
#      0.5000000020876758 - 1.1903487689667922e-16im
#      0.1666666668272571 + 1.094023586503789e-17im
#     0.04166666667813741 + 6.473727660206531e-17im
#    0.008333333334098114 + 3.990369718397902e-17im
#   0.0013888888889365958 + 3.247230688362854e-17im
#  0.00019841269841549546 + 7.495539105349965e-18im
#    2.480158730180371e-5 + 1.7641728122591193e-17im
#    2.755731922299276e-6 + 9.574628306726111e-18im

# %%
f = θ -> exp(exp(im*θ))

@manipulate for n = 1:10
    θ = range(0,2π; length=n+1)[1:n]
    p = range(0, 2π; length=1000)

    f̂ = fft(f.(θ))/n # [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=0:n-1]

    fₙ = θ -> sum(exp(im*k*θ) * f̂[k+1] for k=0:n-1)

    scatter(θ, real.(f.(θ)); label="samples (re)")
    scatter!(θ, imag.(f.(θ)); label="samples (im)")
    plot!(p, real.(f.(p)); label="function (re)")
    plot!(p, imag.(f.(p)); label="function (im)")
    plot!(p, real.(fₙ.(p)); label="approx (re)")
    plot!(p, imag.(fₙ.(p)); label="approx (im)")
end
# f_n interpolates f at θ
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["n"], Dict{Symbol, Any}(:className => "interact ", :style => Dict{Any, Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol, Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol, Any}(:max => 10, :min => 1, :attributes => Dict{Any, Any}(:type => "range", Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}", "orient" => "horizontal"), :step => 1, :className => "slider slider is-fullwidth", :style => Dict{Any, Any}()))], Dict{Symbol, Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol, Any}(:a
# ...

# %%
# Non-Taylor series
f = θ -> exp(cos(θ-0.1))

@manipulate for n = 1:10
    θ = range(0,2π; length=n+1)[1:n]
    p = range(0, 2π; length=1000)

    f̂ = fft(f.(θ))/n # [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=0:n-1]

    # Taylor approximation to something with negative Fourier coefficients
    fₙ = θ -> sum(exp(im*k*θ) * f̂[k+1] for k=0:n-1)

    scatter(θ, real.(f.(θ)); label="samples", legend=:bottomleft)
    scatter!(θ, zero(θ); label="samples (im)")    
    plot!(p, real.(f.(p)); label="function")
    plot!(p, real.(fₙ.(p)); label="approx (re)")
    plot!(p, imag.(fₙ.(p)); label="approx (im)")
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["n"], Dict{Symbol, Any}(:className => "interact ", :style => Dict{Any, Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol, Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol, Any}(:max => 10, :min => 1, :attributes => Dict{Any, Any}(:type => "range", Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}", "orient" => "horizontal"), :step => 1, :className => "slider slider is-fullwidth", :style => Dict{Any, Any}()))], Dict{Symbol, Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol, Any}(:a
# ...

# %%
f = θ -> sign(θ-0.5) * (θ-0.5) * θ * (2π-θ)

@manipulate for m = 0:10
    n = 2m+1
    θ = range(0,2π; length=n+1)[1:n]
    p = range(0, 2π; length=1000)

    f̂ = [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=-m:m]
    # approximate Fourier series includes + and - coefficients
    fₙ = θ -> sum(exp(im*k*θ) * f̂[k+m+1] for k=-m:m)

    scatter(θ, real.(f.(θ)); label="samples", legend=:bottomright)
    scatter!(θ, zero(θ); label="samples (im)")    
    plot!(p, real.(f.(p)); label="function")
    plot!(p, real.(fₙ.(p)); label="approx (re)")
    plot!(p, imag.(fₙ.(p)); label="approx (im)")
end

# For non-Taylor Fourier series, we need negative and positive coefficients to converge
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["m"], Dict{Symbol, Any}(:className => "interact ", :style => Dict{Any, Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol, Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol, Any}(:max => 10, :min => 0, :attributes => Dict{Any, Any}(:type => "range", Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}", "orient" => "horizontal"), :step => 1, :className => "slider slider is-fullwidth", :style => Dict{Any, Any}()))], Dict{Symbol, Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol, Any}(:a
# ...

# %%
# Use Fourier to approximate Runge's function
# Saw in labs using monomials interpolating at evenly spaced did not work well
g = x -> 1/(25x^2+1)
f = θ -> g(cos(θ))

@manipulate for m = 1:100
    n = 2m+1
    θ = range(0,2π; length=n+1)[1:n]
    p = range(0,2π; length=1000)

    f̂ = [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=-m:m]
    fₙ = θ -> sum(exp(im*k*θ) * f̂[k+m+1] for k=-m:m)

    plot(p, real(f.(p)); label="function")
    plot!(p, real(fₙ.(p)); label="approx")
    scatter!(θ, f.(θ); label="samples")
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["m"], Dict{Symbol, Any}(:className => "interact ", :style => Dict{Any, Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol, Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol, Any}(:max => 100, :min => 1, :attributes => Dict{Any, Any}(:type => "range", Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}", "orient" => "horizontal"), :step => 1, :className => "slider slider is-fullwidth", :style => Dict{Any, Any}()))], Dict{Symbol, Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol, Any}(:
# ...

# %%
g = x -> 1/(25x^2+1)
f = θ -> g(cos(θ))

@manipulate for m = 1:100
    n = 2m+1
    θ = range(0,2π; length=n+1)[1:n]
    p = range(-1,1; length=1000)

    f̂ = [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=-m:m]
    fₙ = θ -> sum(exp(im*k*θ) * f̂[k+m+1] for k=-m:m)
    gₙ = x -> real(fₙ(acos(x)))

    x = cos.(θ)
    plot(p, g.(p); label="function")
    plot!(p, gₙ.(p); label="approx")
    scatter!(x, g.(x); label="samples")
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["m"], Dict{Symbol, Any}(:className => "interact ", :style => Dict{Any, Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol, Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol, Any}(:max => 100, :min => 1, :attributes => Dict{Any, Any}(:type => "range", Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}", "orient" => "horizontal"), :step => 1, :className => "slider slider is-fullwidth", :style => Dict{Any, Any}()))], Dict{Symbol, Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol, Any}(:
# ...

# %%
g = x -> 1/(25x^2+1)

@manipulate for m = 1:100
    n = 2m+1
    θ = range(0,2π; length=n+1)[1:n]
    p = range(-1,1; length=1000)
    
    f = θ -> g(cos(θ))

    c = real([sum(cos(k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=0:m])

    fₙ = θ -> c[1] + 2sum(cos(k*θ) * c[k+1] for k=1:m)
    gₙ = x -> fₙ(acos(x))

    x = cos.(θ)
    plot(p, g.(p); label="function")
    plot!(p, gₙ.(p); label="approx")
    scatter!(x, g.(x); label="samples")
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["m"], Dict{Symbol, Any}(:className => "interact ", :style => Dict{Any, Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol, Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol, Any}(:max => 100, :min => 1, :attributes => Dict{Any, Any}(:type => "range", Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}", "orient" => "horizontal"), :step => 1, :className => "slider slider is-fullwidth", :style => Dict{Any, Any}()))], Dict{Symbol, Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol, Any}(:
# ...

# %%
m = 20
n = 2m+1
f = θ -> sign(θ-2)*((θ-2)*θ*(2π-θ))^2
θ = range(0,2π; length=n+1)[1:n]
g = range(0,2π; length=1000)
scatter(θ, f.(θ); label="samples")
plot!(g, f.(g); label="function")


f̂ = [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=-m:m]

fₙ = θ -> sum(exp(im*k*θ) * f̂[k+m+1] for k=-m:m)

plot!(g, real.(fₙ.(g)); label="approx (re)")
plot!(g, imag.(fₙ.(g)); label="approx (im)")

# %%
m = 20
n = 2m+1

θ = range(0,2π; length=n+1)[1:n]
g = range(0,2π; length=1000)


f = θ -> exp(cos(θ))
f̂ = [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=-m:m]
scatter(-m:m, abs.(f̂); yscale=:log10)

f = θ -> exp(exp(im*θ))
f̂ = [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=-m:m]
scatter!(-m:m, abs.(f̂); yscale=:log10)

f = θ -> sign(θ-2)*((θ-2)*θ*(2π-θ))^2
f̂ = [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=-m:m]
scatter!(-m:m, abs.(f̂); yscale=:log10)

# %%
m = 2
n = 2m+1


g = x -> exp(x)
f = θ -> exp(cos(θ))

f.(θ) # g(cos(θ))
f̂ = [sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=-m:m]
fₙ = θ -> sum(exp(im*k*θ) * f̂[k+m+1] for k=-m:m)
fₙ(0.1)
# Out:
# 2.706311688264619 - 6.938893903907228e-18im

# %%
c = real([sum(exp(-im*k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=0:m])
fₙ = θ -> c[1] + sum((exp(im*k*θ) + exp(-im*k*θ))* c[k+1] for k=1:m)
fₙ = θ -> c[1] + 2sum(cos(k*θ) * c[k+1] for k=1:m)
fₙ(0.1)
# Out:
# 2.706311688264619

# %%
g = x -> 1/(25x^2+1)

@manipulate for m = 1:100
    n = 2m+1
    θ = range(0,2π; length=n+1)[1:n]
    p = range(-1,1; length=1000)
    
    f = θ -> g(cos(θ))

    c = real([sum(cos(k*θ[j]) * f(θ[j]) for j = 1:n)/n for k=0:m])

    fₙ = θ -> c[1] + 2sum(cos(k*θ) * c[k+1] for k=1:m)
    gₙ = x -> fₙ(acos(x))

    x = cos.(θ)
    plot(p, g.(p); label="function")
    plot!(p, gₙ.(p); label="approx")
    scatter!(x, g.(x); label="samples")
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["m"], Dict{Symbol, Any}(:className => "interact ", :style => Dict{Any, Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol, Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol, Any}(:max => 100, :min => 1, :attributes => Dict{Any, Any}(:type => "range", Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}", "orient" => "horizontal"), :step => 1, :className => "slider slider is-fullwidth", :style => Dict{Any, Any}()))], Dict{Symbol, Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol, Any}(:
# ...
